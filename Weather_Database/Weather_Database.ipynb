# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 732

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chifeng
# Processing Record 2 of Set 1 | juegang
# Processing Record 3 of Set 1 | olafsvik
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | tilichiki
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | kamenka
# Processing Record 9 of Set 1 | coahuayana
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | plover
# Processing Record 14 of Set 1 | utete
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | broome
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | omboue
# Processing Record 19 of Set 1 | kazachinskoye
# Processing Record 20 of Set 1 | faya
# Processing Record 21 of Set 1 | kikwit
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | sibolga
# Processing Record 24 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 1 | batemans bay
# Processing Record 26 of Set 1 | vestmannaeyjar
# Processing Record 27 of Set 1 | xuddur
# Processing Record 28 of Set 1 | bani
# Processing Record 29 of Set 1 | pangai
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | lompoc
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | shenjiamen
# Processing Record 34 of Set 1 | jamame
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | valka
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | daru
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | sayyan
# Processing Record 43 of Set 1 | kundiawa
# Processing Record 44 of Set 1 | novoagansk
# Processing Record 45 of Set 1 | nabire
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | meiganga
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | oistins
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | faanui
# Processing Record 3 of Set 2 | lubango
# Processing Record 4 of Set 2 | weihe
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | evensk
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | naze
# Processing Record 9 of Set 2 | xinye
# Processing Record 10 of Set 2 | sao filipe
# Processing Record 11 of Set 2 | haines junction
# Processing Record 12 of Set 2 | flinders
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | viesca
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | anloga
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | lavrentiya
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | bengkulu
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | aitape
# Processing Record 25 of Set 2 | abha
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | ortona
# Processing Record 28 of Set 2 | luderitz
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | rikitea
# Processing Record 31 of Set 2 | catamarca
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | bollnas
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | nueva loja
# Processing Record 39 of Set 2 | mabaruma
# Processing Record 40 of Set 2 | puerto quijarro
# Processing Record 41 of Set 2 | husavik
# Processing Record 42 of Set 2 | mercedes
# Processing Record 43 of Set 2 | grindavik
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | killybegs
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | taoudenni
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | kruisfontein
# Processing Record 5 of Set 3 | uyskoye
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | guerrero negro
# Processing Record 8 of Set 3 | yumen
# Processing Record 9 of Set 3 | portland
# Processing Record 10 of Set 3 | dali
# Processing Record 11 of Set 3 | katangli
# Processing Record 12 of Set 3 | nemuro
# Processing Record 13 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 3 | burns lake
# Processing Record 15 of Set 3 | gamboma
# Processing Record 16 of Set 3 | bluff
# Processing Record 17 of Set 3 | esperance
# Processing Record 18 of Set 3 | yeppoon
# Processing Record 19 of Set 3 | boda
# Processing Record 20 of Set 3 | sao felix do xingu
# Processing Record 21 of Set 3 | kampene
# Processing Record 22 of Set 3 | kantunilkin
# Processing Record 23 of Set 3 | kaeo
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 3 | yambio
# Processing Record 27 of Set 3 | burnie
# Processing Record 28 of Set 3 | waipawa
# Processing Record 29 of Set 3 | annau
# Processing Record 30 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 31 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | acapulco
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | zhigansk
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | berlevag
# Processing Record 39 of Set 3 | nikolskoye
# Processing Record 40 of Set 3 | willowick
# Processing Record 41 of Set 3 | ancud
# Processing Record 42 of Set 3 | darhan
# Processing Record 43 of Set 3 | acin
# City not found. Skipping...
# Processing Record 44 of Set 3 | chadiza
# Processing Record 45 of Set 3 | najran
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | hervey bay
# Processing Record 48 of Set 3 | victoria
# Processing Record 49 of Set 3 | port alfred
# Processing Record 50 of Set 3 | komsomolskiy
# Processing Record 1 of Set 4 | aklavik
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | vila franca do campo
# Processing Record 4 of Set 4 | montes claros
# Processing Record 5 of Set 4 | robertsport
# Processing Record 6 of Set 4 | coquimbo
# Processing Record 7 of Set 4 | norman wells
# Processing Record 8 of Set 4 | saint-pierre
# Processing Record 9 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 10 of Set 4 | souillac
# Processing Record 11 of Set 4 | samarai
# Processing Record 12 of Set 4 | hamilton
# Processing Record 13 of Set 4 | bilibino
# Processing Record 14 of Set 4 | itarema
# Processing Record 15 of Set 4 | chuy
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 4 | butaritari
# Processing Record 19 of Set 4 | viransehir
# Processing Record 20 of Set 4 | porto santo
# Processing Record 21 of Set 4 | aswan
# Processing Record 22 of Set 4 | dunedin
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 4 | auki
# Processing Record 26 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 27 of Set 4 | sobolevo
# Processing Record 28 of Set 4 | kiama
# Processing Record 29 of Set 4 | xinzhou
# Processing Record 30 of Set 4 | cayenne
# Processing Record 31 of Set 4 | padang
# Processing Record 32 of Set 4 | vanavara
# Processing Record 33 of Set 4 | paita
# Processing Record 34 of Set 4 | pisco
# Processing Record 35 of Set 4 | along
# Processing Record 36 of Set 4 | lasa
# Processing Record 37 of Set 4 | cody
# Processing Record 38 of Set 4 | millerovo
# Processing Record 39 of Set 4 | dipkarpaz
# City not found. Skipping...
# Processing Record 40 of Set 4 | kieta
# Processing Record 41 of Set 4 | noshiro
# Processing Record 42 of Set 4 | vaini
# Processing Record 43 of Set 4 | planeta rica
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | qaanaaq
# Processing Record 46 of Set 4 | spaichingen
# Processing Record 47 of Set 4 | thunder bay
# Processing Record 48 of Set 4 | sao joao da barra
# Processing Record 49 of Set 4 | teguldet
# Processing Record 50 of Set 4 | gobabis
# Processing Record 1 of Set 5 | yankton
# Processing Record 2 of Set 5 | shelburne
# Processing Record 3 of Set 5 | alofi
# Processing Record 4 of Set 5 | yar-sale
# Processing Record 5 of Set 5 | antipovka
# Processing Record 6 of Set 5 | chara
# Processing Record 7 of Set 5 | ostrovnoy
# Processing Record 8 of Set 5 | elsmere
# Processing Record 9 of Set 5 | saint-joseph
# Processing Record 10 of Set 5 | saint george
# Processing Record 11 of Set 5 | coihaique
# Processing Record 12 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 5 | etchojoa
# Processing Record 14 of Set 5 | ballina
# Processing Record 15 of Set 5 | liberal
# Processing Record 16 of Set 5 | alice springs
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | provideniya
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | laguna
# Processing Record 21 of Set 5 | mandalgovi
# Processing Record 22 of Set 5 | nara
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | nerchinskiy zavod
# Processing Record 25 of Set 5 | huarmey
# Processing Record 26 of Set 5 | huntsville
# Processing Record 27 of Set 5 | lorengau
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | college
# Processing Record 30 of Set 5 | akdepe
# Processing Record 31 of Set 5 | bitlis
# Processing Record 32 of Set 5 | georgetown
# Processing Record 33 of Set 5 | grand gaube
# Processing Record 34 of Set 5 | enshi
# Processing Record 35 of Set 5 | altamira
# Processing Record 36 of Set 5 | narasannapeta
# Processing Record 37 of Set 5 | abadan
# Processing Record 38 of Set 5 | the valley
# Processing Record 39 of Set 5 | puerto ayacucho
# Processing Record 40 of Set 5 | karratha
# Processing Record 41 of Set 5 | tessalit
# Processing Record 42 of Set 5 | popondetta
# Processing Record 43 of Set 5 | kavaratti
# Processing Record 44 of Set 5 | kidal
# Processing Record 45 of Set 5 | solnechnyy
# Processing Record 46 of Set 5 | vao
# Processing Record 47 of Set 5 | magadan
# Processing Record 48 of Set 5 | adrar
# Processing Record 49 of Set 5 | mbandaka
# Processing Record 50 of Set 5 | gaoyou
# Processing Record 1 of Set 6 | lata
# Processing Record 2 of Set 6 | nouakchott
# Processing Record 3 of Set 6 | ileza
# Processing Record 4 of Set 6 | doha
# Processing Record 5 of Set 6 | gerede
# Processing Record 6 of Set 6 | san patricio
# Processing Record 7 of Set 6 | korla
# Processing Record 8 of Set 6 | juneau
# Processing Record 9 of Set 6 | salym
# Processing Record 10 of Set 6 | andra
# Processing Record 11 of Set 6 | acatlan
# Processing Record 12 of Set 6 | labuan
# Processing Record 13 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 6 | rivera
# Processing Record 15 of Set 6 | port elizabeth
# Processing Record 16 of Set 6 | unity
# Processing Record 17 of Set 6 | novokayakent
# Processing Record 18 of Set 6 | opobo
# City not found. Skipping...
# Processing Record 19 of Set 6 | praia da vitoria
# Processing Record 20 of Set 6 | yerbogachen
# Processing Record 21 of Set 6 | kang
# Processing Record 22 of Set 6 | verkhnevilyuysk
# Processing Record 23 of Set 6 | thompson
# Processing Record 24 of Set 6 | portsmouth
# Processing Record 25 of Set 6 | subacius
# City not found. Skipping...
# Processing Record 26 of Set 6 | te anau
# Processing Record 27 of Set 6 | fairbanks
# Processing Record 28 of Set 6 | gravdal
# Processing Record 29 of Set 6 | zhuanghe
# Processing Record 30 of Set 6 | rocha
# Processing Record 31 of Set 6 | norrtalje
# Processing Record 32 of Set 6 | sumbe
# Processing Record 33 of Set 6 | katobu
# Processing Record 34 of Set 6 | lodja
# Processing Record 35 of Set 6 | sinnamary
# Processing Record 36 of Set 6 | anton lizardo
# Processing Record 37 of Set 6 | turayf
# Processing Record 38 of Set 6 | alta
# Processing Record 39 of Set 6 | bonfim
# Processing Record 40 of Set 6 | corabia
# Processing Record 41 of Set 6 | meulaboh
# Processing Record 42 of Set 6 | orange
# Processing Record 43 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 6 | tunxi
# City not found. Skipping...
# Processing Record 45 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 6 | srednekolymsk
# Processing Record 47 of Set 6 | avera
# Processing Record 48 of Set 6 | namibe
# Processing Record 49 of Set 6 | shymkent
# Processing Record 50 of Set 6 | canon city
# Processing Record 1 of Set 7 | churapcha
# Processing Record 2 of Set 7 | leninskoye
# Processing Record 3 of Set 7 | baoding
# Processing Record 4 of Set 7 | panacan
# Processing Record 5 of Set 7 | iqaluit
# Processing Record 6 of Set 7 | lithakia
# Processing Record 7 of Set 7 | saurimo
# Processing Record 8 of Set 7 | moose factory
# Processing Record 9 of Set 7 | nalut
# Processing Record 10 of Set 7 | saint-philippe
# Processing Record 11 of Set 7 | cap malheureux
# Processing Record 12 of Set 7 | hami
# Processing Record 13 of Set 7 | orlovo
# Processing Record 14 of Set 7 | poya
# Processing Record 15 of Set 7 | kuandian
# Processing Record 16 of Set 7 | carballo
# Processing Record 17 of Set 7 | santiago
# Processing Record 18 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 7 | trudarmeyskiy
# Processing Record 20 of Set 7 | lagoa
# Processing Record 21 of Set 7 | itaituba
# Processing Record 22 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 7 | rawson
# Processing Record 24 of Set 7 | mount isa
# Processing Record 25 of Set 7 | waingapu
# Processing Record 26 of Set 7 | maceio
# Processing Record 27 of Set 7 | lewisporte
# Processing Record 28 of Set 7 | codrington
# Processing Record 29 of Set 7 | palmer
# Processing Record 30 of Set 7 | ilulissat
# Processing Record 31 of Set 7 | mount darwin
# Processing Record 32 of Set 7 | peno
# Processing Record 33 of Set 7 | namatanai
# Processing Record 34 of Set 7 | santa cruz
# Processing Record 35 of Set 7 | port-gentil
# Processing Record 36 of Set 7 | porbandar
# Processing Record 37 of Set 7 | pinega
# Processing Record 38 of Set 7 | wawa
# Processing Record 39 of Set 7 | jaguaruna
# Processing Record 40 of Set 7 | jalu
# Processing Record 41 of Set 7 | varzea da palma
# Processing Record 42 of Set 7 | margate
# Processing Record 43 of Set 7 | kirkland lake
# Processing Record 44 of Set 7 | wukari
# Processing Record 45 of Set 7 | bria
# Processing Record 46 of Set 7 | liberty
# Processing Record 47 of Set 7 | salalah
# Processing Record 48 of Set 7 | nova olimpia
# Processing Record 49 of Set 7 | valdivia
# Processing Record 50 of Set 7 | santa helena
# Processing Record 1 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 8 | baiao
# Processing Record 3 of Set 8 | bathsheba
# Processing Record 4 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 8 | kutum
# Processing Record 6 of Set 8 | fukue
# Processing Record 7 of Set 8 | tlahualilo
# City not found. Skipping...
# Processing Record 8 of Set 8 | kuragino
# Processing Record 9 of Set 8 | marsa matruh
# Processing Record 10 of Set 8 | nador
# Processing Record 11 of Set 8 | kenai
# Processing Record 12 of Set 8 | touros
# Processing Record 13 of Set 8 | nanortalik
# Processing Record 14 of Set 8 | toucheng
# Processing Record 15 of Set 8 | bonavista
# Processing Record 16 of Set 8 | yantal
# Processing Record 17 of Set 8 | maturin
# Processing Record 18 of Set 8 | los llanos de aridane
# Processing Record 19 of Set 8 | leningradskiy
# Processing Record 20 of Set 8 | dolzhanskaya
# Processing Record 21 of Set 8 | roma
# Processing Record 22 of Set 8 | puri
# Processing Record 23 of Set 8 | tulum
# Processing Record 24 of Set 8 | mackenzie
# Processing Record 25 of Set 8 | boa vista
# Processing Record 26 of Set 8 | marawi
# Processing Record 27 of Set 8 | noumea
# Processing Record 28 of Set 8 | hofn
# Processing Record 29 of Set 8 | chuguyevka
# Processing Record 30 of Set 8 | bambous virieux
# Processing Record 31 of Set 8 | umm lajj
# Processing Record 32 of Set 8 | awbari
# Processing Record 33 of Set 8 | srandakan
# Processing Record 34 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 8 | linguere
# Processing Record 36 of Set 8 | paamiut
# Processing Record 37 of Set 8 | saint-henri-de-levis
# City not found. Skipping...
# Processing Record 38 of Set 8 | sohbatpur
# Processing Record 39 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 40 of Set 8 | ilhabela
# Processing Record 41 of Set 8 | kodinsk
# Processing Record 42 of Set 8 | sistranda
# Processing Record 43 of Set 8 | amahai
# Processing Record 44 of Set 8 | lumatil
# Processing Record 45 of Set 8 | otane
# Processing Record 46 of Set 8 | singleton
# Processing Record 47 of Set 8 | llanes
# Processing Record 48 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 8 | dumas
# Processing Record 50 of Set 8 | shahreza
# Processing Record 1 of Set 9 | ivdel
# Processing Record 2 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 9 | sao raimundo nonato
# Processing Record 5 of Set 9 | manga
# Processing Record 6 of Set 9 | moron
# Processing Record 7 of Set 9 | mwinilunga
# Processing Record 8 of Set 9 | kirakira
# Processing Record 9 of Set 9 | pavlogradka
# Processing Record 10 of Set 9 | rio gallegos
# Processing Record 11 of Set 9 | mount gambier
# Processing Record 12 of Set 9 | pochutla
# Processing Record 13 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 14 of Set 9 | pangoa
# Processing Record 15 of Set 9 | santa ines
# Processing Record 16 of Set 9 | mastic beach
# Processing Record 17 of Set 9 | colomi
# Processing Record 18 of Set 9 | moroni
# Processing Record 19 of Set 9 | cangucu
# Processing Record 20 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 9 | port hawkesbury
# Processing Record 22 of Set 9 | ibra
# Processing Record 23 of Set 9 | candawaga
# City not found. Skipping...
# Processing Record 24 of Set 9 | khao yoi
# Processing Record 25 of Set 9 | tarko-sale
# Processing Record 26 of Set 9 | manggar
# Processing Record 27 of Set 9 | rockingham
# Processing Record 28 of Set 9 | port hardy
# Processing Record 29 of Set 9 | kologriv
# Processing Record 30 of Set 9 | culver city
# Processing Record 31 of Set 9 | honiara
# Processing Record 32 of Set 9 | hokitika
# Processing Record 33 of Set 9 | yulara
# Processing Record 34 of Set 9 | novo aripuana
# Processing Record 35 of Set 9 | henties bay
# Processing Record 36 of Set 9 | port lincoln
# Processing Record 37 of Set 9 | quatre cocos
# Processing Record 38 of Set 9 | tamiahua
# Processing Record 39 of Set 9 | beringovskiy
# Processing Record 40 of Set 9 | baykit
# Processing Record 41 of Set 9 | lerwick
# Processing Record 42 of Set 9 | mikkeli
# Processing Record 43 of Set 9 | moulins
# Processing Record 44 of Set 9 | jiaocheng
# Processing Record 45 of Set 9 | pithoragarh
# Processing Record 46 of Set 9 | lai
# Processing Record 47 of Set 9 | tsogni
# Processing Record 48 of Set 9 | krasnoselkup
# Processing Record 49 of Set 9 | champasak
# Processing Record 50 of Set 9 | cristobal obregon
# Processing Record 1 of Set 10 | baikunthpur
# Processing Record 2 of Set 10 | merauke
# Processing Record 3 of Set 10 | kupang
# Processing Record 4 of Set 10 | xai-xai
# Processing Record 5 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 10 | narsaq
# Processing Record 8 of Set 10 | ocos
# Processing Record 9 of Set 10 | mananara
# Processing Record 10 of Set 10 | harper
# Processing Record 11 of Set 10 | uray
# Processing Record 12 of Set 10 | russell
# Processing Record 13 of Set 10 | nizhniy kuranakh
# Processing Record 14 of Set 10 | san quintin
# Processing Record 15 of Set 10 | fortuna
# Processing Record 16 of Set 10 | balingasay
# Processing Record 17 of Set 10 | bloomington
# Processing Record 18 of Set 10 | hovd
# Processing Record 19 of Set 10 | makamba
# Processing Record 20 of Set 10 | cuiluan
# Processing Record 21 of Set 10 | kapuskasing
# Processing Record 22 of Set 10 | airai
# Processing Record 23 of Set 10 | synya
# Processing Record 24 of Set 10 | tumbi
# Processing Record 25 of Set 10 | belawan
# Processing Record 26 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 27 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 10 | baicheng
# Processing Record 29 of Set 10 | huaihua
# Processing Record 30 of Set 10 | savannah bight
# Processing Record 31 of Set 10 | kudahuvadhoo
# Processing Record 32 of Set 10 | varhaug
# Processing Record 33 of Set 10 | presidente dutra
# Processing Record 34 of Set 10 | jiuquan
# Processing Record 35 of Set 10 | liepaja
# Processing Record 36 of Set 10 | mayor pablo lagerenza
# Processing Record 37 of Set 10 | sitka
# Processing Record 38 of Set 10 | igrim
# Processing Record 39 of Set 10 | samagaltay
# Processing Record 40 of Set 10 | tholos
# Processing Record 41 of Set 10 | kasaragod
# Processing Record 42 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 10 | kristiansund
# Processing Record 44 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 10 | ulaanbaatar
# Processing Record 46 of Set 10 | la ronge
# Processing Record 47 of Set 10 | novikovo
# Processing Record 48 of Set 10 | nome
# Processing Record 49 of Set 10 | wanxian
# Processing Record 50 of Set 10 | sri aman
# Processing Record 1 of Set 11 | sungaipenuh
# Processing Record 2 of Set 11 | walvis bay
# Processing Record 3 of Set 11 | damietta
# Processing Record 4 of Set 11 | castrillon
# Processing Record 5 of Set 11 | barrhead
# Processing Record 6 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 11 | tocopilla
# Processing Record 8 of Set 11 | buriti bravo
# Processing Record 9 of Set 11 | seoul
# Processing Record 10 of Set 11 | rudbar
# Processing Record 11 of Set 11 | sindor
# Processing Record 12 of Set 11 | vytegra
# Processing Record 13 of Set 11 | hobyo
# Processing Record 14 of Set 11 | inyonga
# Processing Record 15 of Set 11 | isla vista
# Processing Record 16 of Set 11 | dongli
# Processing Record 17 of Set 11 | pandamatenga
# Processing Record 18 of Set 11 | armidale
# Processing Record 19 of Set 11 | salinas
# Processing Record 20 of Set 11 | yushu
# Processing Record 21 of Set 11 | katherine
# Processing Record 22 of Set 11 | chipoka
# Processing Record 23 of Set 11 | ipswich
# Processing Record 24 of Set 11 | myaundzha
# Processing Record 25 of Set 11 | camana
# Processing Record 26 of Set 11 | half moon bay
# Processing Record 27 of Set 11 | zuenoula
# Processing Record 28 of Set 11 | flin flon
# Processing Record 29 of Set 11 | neiafu
# Processing Record 30 of Set 11 | palaikastron
# Processing Record 31 of Set 11 | kununurra
# Processing Record 32 of Set 11 | zaysan
# Processing Record 33 of Set 11 | kanniyakumari
# Processing Record 34 of Set 11 | moindou
# Processing Record 35 of Set 11 | puerto escondido
# Processing Record 36 of Set 11 | sorong
# Processing Record 37 of Set 11 | tautira
# Processing Record 38 of Set 11 | kendal
# Processing Record 39 of Set 11 | myitkyina
# Processing Record 40 of Set 11 | bella union
# Processing Record 41 of Set 11 | axim
# Processing Record 42 of Set 11 | kedrovyy
# Processing Record 43 of Set 11 | nuuk
# Processing Record 44 of Set 11 | toda raisingh
# Processing Record 45 of Set 11 | coos bay
# Processing Record 46 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 47 of Set 11 | seabra
# Processing Record 48 of Set 11 | westerland
# Processing Record 49 of Set 11 | linshu
# City not found. Skipping...
# Processing Record 50 of Set 11 | kamaishi
# Processing Record 1 of Set 12 | waddan
# Processing Record 2 of Set 12 | cairns
# Processing Record 3 of Set 12 | tarakan
# Processing Record 4 of Set 12 | erenhot
# Processing Record 5 of Set 12 | chapais
# Processing Record 6 of Set 12 | morondava
# Processing Record 7 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 12 | bismarck
# Processing Record 9 of Set 12 | mantua
# Processing Record 10 of Set 12 | mankera
# Processing Record 11 of Set 12 | nizwa
# Processing Record 12 of Set 12 | san cristobal
# Processing Record 13 of Set 12 | penzance
# Processing Record 14 of Set 12 | chumikan
# Processing Record 15 of Set 12 | aguimes
# Processing Record 16 of Set 12 | guatire
# Processing Record 17 of Set 12 | pafos
# Processing Record 18 of Set 12 | horasan
# Processing Record 19 of Set 12 | somvarpet
# Processing Record 20 of Set 12 | bijie
# Processing Record 21 of Set 12 | labuhan
# Processing Record 22 of Set 12 | luwingu
# Processing Record 23 of Set 12 | dong hoi
# Processing Record 24 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 12 | fare
# Processing Record 26 of Set 12 | camopi
# Processing Record 27 of Set 12 | petrovskoye
# Processing Record 28 of Set 12 | angoche
# Processing Record 29 of Set 12 | kambove
# Processing Record 30 of Set 12 | dillon
# Processing Record 31 of Set 12 | oro valley
# Processing Record 32 of Set 12 | rudnaya pristan
# Processing Record 33 of Set 12 | wanning
# Processing Record 34 of Set 12 | shakiso
# Processing Record 35 of Set 12 | dhidhdhoo
# Processing Record 36 of Set 12 | emerald
# Processing Record 37 of Set 12 | balkhash
# Processing Record 38 of Set 12 | sorland
# Processing Record 39 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 40 of Set 12 | caravelas
# Processing Record 41 of Set 12 | butte
# Processing Record 42 of Set 12 | yuksekova
# Processing Record 43 of Set 12 | grande-riviere
# City not found. Skipping...
# Processing Record 44 of Set 12 | shingu
# Processing Record 45 of Set 12 | presidencia roque saenz pena
# Processing Record 46 of Set 12 | puerto gaitan
# Processing Record 47 of Set 12 | redcliffe
# Processing Record 48 of Set 12 | liuzhou
# Processing Record 49 of Set 12 | north platte
# Processing Record 50 of Set 12 | bakchar
# Processing Record 1 of Set 13 | goias
# Processing Record 2 of Set 13 | kanturk
# Processing Record 3 of Set 13 | mbanza-ngungu
# Processing Record 4 of Set 13 | torrington
# Processing Record 5 of Set 13 | tual
# Processing Record 6 of Set 13 | amapa
# Processing Record 7 of Set 13 | goya
# Processing Record 8 of Set 13 | deputatskiy
# Processing Record 9 of Set 13 | sotouboua
# Processing Record 10 of Set 13 | altamura
# Processing Record 11 of Set 13 | pregradnoye
# Processing Record 12 of Set 13 | makakilo city
# Processing Record 13 of Set 13 | formosa
# Processing Record 14 of Set 13 | vardo
# Processing Record 15 of Set 13 | ondangwa
# Processing Record 16 of Set 13 | bocaranga
# City not found. Skipping...
# Processing Record 17 of Set 13 | port hedland
# Processing Record 18 of Set 13 | kingston
# Processing Record 19 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 13 | tromso
# Processing Record 21 of Set 13 | talmenka
# Processing Record 22 of Set 13 | sogdiondon
# City not found. Skipping...
# Processing Record 23 of Set 13 | ahuimanu
# Processing Record 24 of Set 13 | piacabucu
# Processing Record 25 of Set 13 | gillette
# Processing Record 26 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 27 of Set 13 | pavlodar
# Processing Record 28 of Set 13 | tadine
# Processing Record 29 of Set 13 | pio xii
# Processing Record 30 of Set 13 | lokachi
# Processing Record 31 of Set 13 | lixourion
# Processing Record 32 of Set 13 | tiznit
# Processing Record 33 of Set 13 | chebsara
# Processing Record 34 of Set 13 | arlit
# Processing Record 35 of Set 13 | wuhan
# Processing Record 36 of Set 13 | rohatyn
# Processing Record 37 of Set 13 | kungurtug
# Processing Record 38 of Set 13 | ginir
# Processing Record 39 of Set 13 | madera
# Processing Record 40 of Set 13 | wanaka
# Processing Record 41 of Set 13 | garowe
# Processing Record 42 of Set 13 | kasongo-lunda
# Processing Record 43 of Set 13 | manzanillo
# Processing Record 44 of Set 13 | xiamen
# Processing Record 45 of Set 13 | la asuncion
# Processing Record 46 of Set 13 | kahului
# Processing Record 47 of Set 13 | verkh-usugli
# Processing Record 48 of Set 13 | pathein
# Processing Record 49 of Set 13 | dossor
# Processing Record 50 of Set 13 | lander
# Processing Record 1 of Set 14 | mirnyy
# Processing Record 2 of Set 14 | gao
# Processing Record 3 of Set 14 | lima
# Processing Record 4 of Set 14 | kendari
# Processing Record 5 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 14 | antigonish
# Processing Record 7 of Set 14 | burgeo
# Processing Record 8 of Set 14 | sarany
# Processing Record 9 of Set 14 | guapi
# Processing Record 10 of Set 14 | port moresby
# Processing Record 11 of Set 14 | gushikawa
# Processing Record 12 of Set 14 | safford
# Processing Record 13 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 14 | gemena
# Processing Record 15 of Set 14 | pitimbu
# Processing Record 16 of Set 14 | vila do maio
# Processing Record 17 of Set 14 | sept-iles
# Processing Record 18 of Set 14 | oussouye
# Processing Record 19 of Set 14 | alyangula
# Processing Record 20 of Set 14 | atar
# Processing Record 21 of Set 14 | barra
# Processing Record 22 of Set 14 | redwater
# Processing Record 23 of Set 14 | filimonovo
# Processing Record 24 of Set 14 | isla mujeres
# Processing Record 25 of Set 14 | bom jesus dos perdoes
# Processing Record 26 of Set 14 | heze
# Processing Record 27 of Set 14 | vila velha
# Processing Record 28 of Set 14 | passo de camaragibe
# Processing Record 29 of Set 14 | jacareacanga
# Processing Record 30 of Set 14 | fredericksburg
# Processing Record 31 of Set 14 | tahta
# Processing Record 32 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 14 | kocevje
# Processing Record 34 of Set 14 | carson city
# Processing Record 35 of Set 14 | amarante do maranhao
# Processing Record 36 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 14 | svetlograd
# Processing Record 38 of Set 14 | ponta delgada
# Processing Record 39 of Set 14 | hohhot
# Processing Record 40 of Set 14 | gat
# Processing Record 41 of Set 14 | batsfjord
# Processing Record 42 of Set 14 | esna
# Processing Record 43 of Set 14 | ibiruba
# Processing Record 44 of Set 14 | arcachon
# Processing Record 45 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 14 | auchi
# Processing Record 47 of Set 14 | marinette
# Processing Record 48 of Set 14 | muravlenko
# Processing Record 49 of Set 14 | kulhudhuffushi
# Processing Record 50 of Set 14 | urumqi
# Processing Record 1 of Set 15 | saint-augustin
# Processing Record 2 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 15 | navirai
# Processing Record 4 of Set 15 | kamarion
# Processing Record 5 of Set 15 | swan hill
# Processing Record 6 of Set 15 | panjab
# Processing Record 7 of Set 15 | lucapa
# Processing Record 8 of Set 15 | ashland
# Processing Record 9 of Set 15 | petatlan
# Processing Record 10 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 15 | alamogordo
# Processing Record 12 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 15 | tecoanapa
# Processing Record 14 of Set 15 | banes
# Processing Record 15 of Set 15 | quelimane
# Processing Record 16 of Set 15 | mayumba
# Processing Record 17 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 18 of Set 15 | aykhal
# Processing Record 19 of Set 15 | sur
# Processing Record 20 of Set 15 | oranjemund
# Processing Record 21 of Set 15 | enumclaw
# Processing Record 22 of Set 15 | troitskoye
# Processing Record 23 of Set 15 | kavieng
# Processing Record 24 of Set 15 | vostok
# Processing Record 25 of Set 15 | okhotsk
# Processing Record 26 of Set 15 | lantawan
# Processing Record 27 of Set 15 | tukrah
# Processing Record 28 of Set 15 | caraquet
# Processing Record 29 of Set 15 | belyy yar
# Processing Record 30 of Set 15 | martapura
# Processing Record 31 of Set 15 | brighton
# Processing Record 32 of Set 15 | vilhena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 668

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Chifeng  42.2683  118.9636     31.80        18           0        5.66
# 1     Juegang  32.3174  121.1855     55.98        71           0       15.68
# 2    Olafsvik  64.8945  -23.7142     31.75        67         100       21.85
# 3    Hermanus -34.4187   19.2345     63.81        84          81        5.41
# 4   Tilichiki  60.4667  166.1000    -12.93        91          91       10.11
# 5   Cape Town -33.9258   18.4232     65.10        87           0        5.75
# 6      Hobart -42.8794  147.3294     77.27        73          40       23.02
# 7     Kamenka  51.3223   42.7678      1.76        97          95        3.29
# 8  Coahuayana  18.7333 -103.6833     69.87        90           0        3.51
# 9   Saskylakh  71.9167  114.0833    -25.71        98         100        6.38
#
#   Country Current Description
# 0      CN           clear sky
# 1      CN           clear sky
# 2      IS     overcast clouds
# 3      ZA       broken clouds
# 4      RU     overcast clouds
# 5      ZA           clear sky
# 6      AU    scattered clouds
# 7      RU     overcast clouds
# 8      MX           clear sky
# 9      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Chifeng      CN  42.2683  118.9636     31.80        18           0
# 1     Juegang      CN  32.3174  121.1855     55.98        71           0
# 2    Olafsvik      IS  64.8945  -23.7142     31.75        67         100
# 3    Hermanus      ZA -34.4187   19.2345     63.81        84          81
# 4   Tilichiki      RU  60.4667  166.1000    -12.93        91          91
# 5   Cape Town      ZA -33.9258   18.4232     65.10        87           0
# 6      Hobart      AU -42.8794  147.3294     77.27        73          40
# 7     Kamenka      RU  51.3223   42.7678      1.76        97          95
# 8  Coahuayana      MX  18.7333 -103.6833     69.87        90           0
# 9   Saskylakh      RU  71.9167  114.0833    -25.71        98         100
#
#    Wind Speed Current Description
# 0        5.66           clear sky
# 1       15.68           clear sky
# 2       21.85     overcast clouds
# 3        5.41       broken clouds
# 4       10.11     overcast clouds
# 5        5.75           clear sky
# 6       23.02    scattered clouds
# 7        3.29     overcast clouds
# 8        3.51           clear sky
# 9        6.38     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
